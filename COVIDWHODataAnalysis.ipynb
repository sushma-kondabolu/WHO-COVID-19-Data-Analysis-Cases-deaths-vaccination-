# %%
import pandas as pd
import numpy as np
from datetime import date
from datetime import timedelta
import seaborn as sns
import matplotlib.pyplot as plt

# %%
daily_cases_data=pd.read_csv('https://covid19.who.int/WHO-COVID-19-global-data.csv')
daily_cases_data
# Out:
#        Date_reported Country_code  ... New_deaths Cumulative_deaths
# 0         2020-01-03           AF  ...          0                 0
# 1         2020-01-04           AF  ...          0                 0
# 2         2020-01-05           AF  ...          0                 0
# 3         2020-01-06           AF  ...          0                 0
# 4         2020-01-07           AF  ...          0                 0
# ...              ...          ...  ...        ...               ...
# 141247    2021-08-16           ZW  ...         19              4109
# 141248    2021-08-17           ZW  ...         29              4138
# 141249    2021-08-18           ZW  ...         18              4156
# 141250    2021-08-19           ZW  ...         25              4181
# 141251    2021-08-20           ZW  ...         17              4198
#
# [141252 rows x 8 columns]

# %%
len(pd.unique(daily_cases_data['Country']))
# Out:
# 237

# %%
daily_cases_data.isnull().sum()
# Out:
# Date_reported          0
# Country_code         596
# Country                0
# WHO_region             0
# New_cases              0
# Cumulative_cases       0
# New_deaths             0
# Cumulative_deaths      0
# dtype: int64

# %%
daily_cases_data[daily_cases_data['Country_code'].isnull()]
# Out:
#       Date_reported Country_code  ... New_deaths Cumulative_deaths
# 85228    2020-01-03          NaN  ...          0                 0
# 85229    2020-01-04          NaN  ...          0                 0
# 85230    2020-01-05          NaN  ...          0                 0
# 85231    2020-01-06          NaN  ...          0                 0
# 85232    2020-01-07          NaN  ...          0                 0
# ...             ...          ...  ...        ...               ...
# 85819    2021-08-16          NaN  ...          0              3277
# 85820    2021-08-17          NaN  ...          8              3285
# 85821    2021-08-18          NaN  ...          3              3288
# 85822    2021-08-19          NaN  ...          0              3288
# 85823    2021-08-20          NaN  ...         28              3316
#
# [596 rows x 8 columns]

# %%
daily_cases_data['Country_code'].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AS', 'AD', 'AO', 'AI', 'AG', 'AR', 'AM', 'AW',
#        'AU', 'AT', 'AZ', 'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ',
#        'BM', 'BT', 'BO', 'XA', 'BA', 'BW', 'BR', 'VG', 'BN', 'BG', 'BF',
#        'BI', 'CV', 'KH', 'CM', 'CA', 'KY', 'CF', 'TD', 'CL', 'CN', 'CO',
#        'KM', 'CG', 'CK', 'CR', 'CI', 'HR', 'CU', 'CW', 'CY', 'CZ', 'KP',
#        'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER', 'EE',
#        'SZ', 'ET', 'FK', 'FO', 'FJ', 'FI', 'FR', 'GF', 'PF', 'GA', 'GM',
#        'GE', 'DE', 'GH', 'GI', 'GR', 'GL', 'GD', 'GP', 'GU', 'GT', 'GG',
#        'GN', 'GW', 'GY', 'HT', 'VA', 'HN', 'HU', 'IS', 'IN', 'ID', 'IR',
#        'IQ', 'IE', 'IM', 'IL', 'IT', 'JM', 'JP', 'JE', 'JO', 'KZ', 'KE',
#        'KI', 'XK', 'KW', 'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI',
#        'LT', 'LU', 'MG', 'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MQ', 'MR',
#        'MU', 'YT', 'MX', 'FM', 'MC', 'MN', 'ME', 'MS', 'MA', 'MZ', 'MM',
# ...

# %%
daily_cases_data.fillna('NM')
# Out:
#        Date_reported Country_code  ... New_deaths Cumulative_deaths
# 0         2020-01-03           AF  ...          0                 0
# 1         2020-01-04           AF  ...          0                 0
# 2         2020-01-05           AF  ...          0                 0
# 3         2020-01-06           AF  ...          0                 0
# 4         2020-01-07           AF  ...          0                 0
# ...              ...          ...  ...        ...               ...
# 141247    2021-08-16           ZW  ...         19              4109
# 141248    2021-08-17           ZW  ...         29              4138
# 141249    2021-08-18           ZW  ...         18              4156
# 141250    2021-08-19           ZW  ...         25              4181
# 141251    2021-08-20           ZW  ...         17              4198
#
# [141252 rows x 8 columns]

# %%
daily_cases_data[daily_cases_data['Country_code']==' ']
# Out:
#       Date_reported Country_code  ... New_deaths Cumulative_deaths
# 94168    2020-01-03               ...          0                 0
# 94169    2020-01-04               ...          0                 0
# 94170    2020-01-05               ...          0                 0
# 94171    2020-01-06               ...          0                 0
# 94172    2020-01-07               ...          0                 0
# ...             ...          ...  ...        ...               ...
# 94759    2021-08-16               ...          0                13
# 94760    2021-08-17               ...          0                13
# 94761    2021-08-18               ...          0                13
# 94762    2021-08-19               ...          0                13
# 94763    2021-08-20               ...          0                13
#
# [596 rows x 8 columns]

# %%
daily_cases_data.groupby('Date_reported').sum()
# Out:
#                New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2020-01-03             0                 0           0                  0
# 2020-01-04             1                 1           0                  0
# 2020-01-05             0                 1           0                  0
# 2020-01-06             3                 4           0                  0
# 2020-01-07             0                 4           0                  0
# ...                  ...               ...         ...                ...
# 2021-08-16        649070         207411859        9448            4363769
# 2021-08-17        530181         207942040        7699            4371468
# 2021-08-18        597146         208539186        8512            4379980
# 2021-08-19        686500         209225686       11704            4391684
# 2021-08-20        650927         209876613        8600            4400284
#
# [596 rows x 4 columns]

# %%
daily_cases_data['Date_reported']=pd.to_datetime(daily_cases_data['Date_reported'], format='%Y-%m-%d')
daily_cases_data
# Out:
#        Date_reported Country_code  ... New_deaths Cumulative_deaths
# 0         2020-01-03           AF  ...          0                 0
# 1         2020-01-04           AF  ...          0                 0
# 2         2020-01-05           AF  ...          0                 0
# 3         2020-01-06           AF  ...          0                 0
# 4         2020-01-07           AF  ...          0                 0
# ...              ...          ...  ...        ...               ...
# 141247    2021-08-16           ZW  ...         19              4109
# 141248    2021-08-17           ZW  ...         29              4138
# 141249    2021-08-18           ZW  ...         18              4156
# 141250    2021-08-19           ZW  ...         25              4181
# 141251    2021-08-20           ZW  ...         17              4198
#
# [141252 rows x 8 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

g1 = sns.lineplot(data=daily_cases_data.groupby('Date_reported').sum(),x='Date_reported',y='New_cases')

#g1.set(xticklabels=[])  # remove the tick labels
g1.set(title='Daily cases count')  # add a title
#g1.set(xlabel='Date')  # remove the axis label
# Out:
# [Text(0.5, 1.0, 'Daily cases count')]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

f1 = sns.lineplot(data=daily_cases_data.groupby('Date_reported').sum(),x='Date_reported',y='New_deaths')

#g1.set(xticklabels=[])  # remove the tick labels
f1.set(title='Daily deaths count')  # add a title
#g1.set(xlabel='Date')  # remove the axis label
# Out:
# [Text(0.5, 1.0, 'Daily deaths count')]

# %%
daily_cases_data['Month_Year']=daily_cases_data['Date_reported'].dt.strftime('%Y-%m')
daily_cases_data
# Out:
#        Date_reported Country_code  ... Cumulative_deaths Month_Year
# 0         2020-01-03           AF  ...                 0    2020-01
# 1         2020-01-04           AF  ...                 0    2020-01
# 2         2020-01-05           AF  ...                 0    2020-01
# 3         2020-01-06           AF  ...                 0    2020-01
# 4         2020-01-07           AF  ...                 0    2020-01
# ...              ...          ...  ...               ...        ...
# 141247    2021-08-16           ZW  ...              4109    2021-08
# 141248    2021-08-17           ZW  ...              4138    2021-08
# 141249    2021-08-18           ZW  ...              4156    2021-08
# 141250    2021-08-19           ZW  ...              4181    2021-08
# 141251    2021-08-20           ZW  ...              4198    2021-08
#
# [141252 rows x 9 columns]

# %%
monthly_data=daily_cases_data.groupby('Month_Year').sum()
monthly_data.reset_index(inplace=True)
monthly_data
# Out:
#    Month_Year  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 0     2020-01       9896             37809         213                911
# 1     2020-02      75484           1634980        2722              46851
# 2     2020-03     714261           8457540       36869             367623
# 3     2020-04    2311268          59681940      189925            4097054
# 4     2020-05    2839643         139552428      154373            9686554
# 5     2020-06    4255980         239198096      147383           13753412
# 6     2020-07    6973488         420888738      174820           19156736
# 7     2020-08    8282767         664627255      189079           24967166
# 8     2020-09    8688221         896416596      165773           29490150
# 9     2020-10   12387725        1238546471      186752           35810210
# 10    2020-11   17067489        1655556836      278311           41479855
# 11    2020-12   19059035        2278346889      346757           52829969
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
ax = sns.barplot(x="Month_Year", y="New_cases", data=monthly_data)
ax

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
ax = sns.lineplot(x="Month_Year", y="New_deaths", data=monthly_data)
ax

# %%
today = date.today()

yesterday = today - timedelta(days=1)

print(yesterday)
# Out:
# 2021-08-21

# %%
def data_by_date(date_chosen):
  cases_by_date=daily_cases_data[daily_cases_data['Date_reported']==str(date_chosen)]
  print('The number of cases on ',date_chosen,' is ',cases_by_date['New_cases'].sum())
  print('The number of cases on ',date_chosen,' is ',cases_by_date['New_deaths'].sum())
  max_cases_country_data=cases_by_date[cases_by_date['New_cases']==cases_by_date['New_cases'].max()]
  print('The country with maximum cases on ',date_chosen,' is ',max_cases_country_data['Country'].values,' with no. of cases: ',max_cases_country_data['New_cases'].values)
  max_deaths_country_data=cases_by_date[cases_by_date['New_deaths']==cases_by_date['New_deaths'].max()]
  print('The country with maximum cases on ',date_chosen,' is ',max_deaths_country_data['Country'].values,' with no. of deaths: ',max_cases_country_data['New_deaths'].values)

# %%
data_by_date(yesterday)
# Out:
# The number of cases on  2021-08-21  is  0
# The number of cases on  2021-08-21  is  0
# The country with maximum cases on  2021-08-21  is  []  with no. of cases:  []
# The country with maximum cases on  2021-08-21  is  []  with no. of deaths:  []

# %%
def data_by_month(given_month):
  cases_by_month=daily_cases_data[daily_cases_data['Month_Year']==str(given_month)]
  print('The number of cases on ',given_month,' is ',cases_by_month['New_cases'].sum())
  print('The number of cases on ',given_month,' is ',cases_by_month['New_deaths'].sum())
  #max_cases_country_data=monthly_data[cases_by_month['New_cases']==cases_by_month['New_cases'].max()]
  #print('The country with maximum cases on ',given_month,' is ',max_cases_country_data['Country'].values,' with no. of cases: ',max_cases_country_data['New_cases'].values)
  #max_deaths_country_data=cases_by_date[cases_by_month['New_deaths']==cases_by_month['New_deaths'].max()]
  #print('The country with maximum cases on ',given_month,' is ',max_deaths_country_data['Country'].values,' with no. of deaths: ',max_cases_country_data['New_deaths'].values)

# %%
data_by_month('2021-01')
# Out:
# The number of cases on  2021-01  is  19753631
# The number of cases on  2021-01  is  424178

# %%
daily_cases_data[daily_cases_data['New_cases']==daily_cases_data['New_cases'].max()]
# Out:
#       Date_reported Country_code  ... Cumulative_deaths Month_Year
# 57706    2021-05-07           IN  ...            234083    2021-05
#
# [1 rows x 9 columns]

# %%
daily_cases_data[daily_cases_data['New_deaths']==daily_cases_data['New_deaths'].max()]
# Out:
#       Date_reported Country_code  ... Cumulative_deaths Month_Year
# 36325    2021-07-21           EC  ...             30744    2021-07
#
# [1 rows x 9 columns]

# %%
daily_cases_data.groupby('Date_reported').sum().max()
# Out:
# New_cases               894879
# Cumulative_cases     209876613
# New_deaths               19833
# Cumulative_deaths      4400284
# dtype: int64

# %%
x=daily_cases_data.groupby('Date_reported').sum().max()
x
# Out:
# New_cases               894879
# Cumulative_cases     209876613
# New_deaths               19833
# Cumulative_deaths      4400284
# dtype: int64

# %%
gen=daily_cases_data.groupby('Date_reported').sum()
gen[gen['New_cases']==x['New_cases']]
# Out:
#                New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2021-04-23        894879         144204003       14838            3177180

# %%
gen[gen['New_deaths']==x['New_deaths']]
# Out:
#                New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2021-07-21        488830         191287776       19833            4119634

# %%
WHO_Rregs_cases_count=daily_cases_data.groupby(['WHO_region'])['New_cases'].sum()
WHO_Rregs_cases_count
# Out:
# WHO_region
# AFRO      5413441
# AMRO     81226913
# EMRO     13935546
# EURO     63296202
# Other         764
# SEARO    40322873
# WPRO      5680874
# Name: New_cases, dtype: int64

# %%
WHO_Rregs_cases_count.plot.pie(autopct="%.1f%%",figsize=(8, 8));

# %%
WHO_Rregs_deaths_count=daily_cases_data.groupby(['WHO_region'])['New_deaths'].sum()
WHO_Rregs_deaths_count
# Out:
# WHO_region
# AFRO      129435
# AMRO     2065166
# EMRO      254470
# EURO     1250224
# Other         13
# SEARO     621356
# WPRO       79620
# Name: New_deaths, dtype: int64

# %%
WHO_Rregs_deaths_count.plot.pie(autopct="%.1f%%",figsize=(8, 8));

# %%
daily_cases_data['Year']=daily_cases_data['Date_reported'].dt.strftime('%Y')
daily_cases_data
# Out:
#        Date_reported Country_code  ... Month_Year  Year
# 0         2020-01-03           AF  ...    2020-01  2020
# 1         2020-01-04           AF  ...    2020-01  2020
# 2         2020-01-05           AF  ...    2020-01  2020
# 3         2020-01-06           AF  ...    2020-01  2020
# 4         2020-01-07           AF  ...    2020-01  2020
# ...              ...          ...  ...        ...   ...
# 141247    2021-08-16           ZW  ...    2021-08  2021
# 141248    2021-08-17           ZW  ...    2021-08  2021
# 141249    2021-08-18           ZW  ...    2021-08  2021
# 141250    2021-08-19           ZW  ...    2021-08  2021
# 141251    2021-08-20           ZW  ...    2021-08  2021
#
# [141252 rows x 10 columns]

# %%
monthly_data['dummy']=pd.to_datetime(monthly_data['Month_Year'], format='%Y-%m')
monthly_data['Year']=monthly_data['dummy'].dt.strftime('%Y')
monthly_data['Month'] = monthly_data['dummy'].dt.month_name()
monthly_data
# Out:
#    Month_Year  New_cases  Cumulative_cases  ...      dummy  Year      Month
# 0     2020-01       9896             37809  ... 2020-01-01  2020    January
# 1     2020-02      75484           1634980  ... 2020-02-01  2020   February
# 2     2020-03     714261           8457540  ... 2020-03-01  2020      March
# 3     2020-04    2311268          59681940  ... 2020-04-01  2020      April
# 4     2020-05    2839643         139552428  ... 2020-05-01  2020        May
# 5     2020-06    4255980         239198096  ... 2020-06-01  2020       June
# 6     2020-07    6973488         420888738  ... 2020-07-01  2020       July
# 7     2020-08    8282767         664627255  ... 2020-08-01  2020     August
# 8     2020-09    8688221         896416596  ... 2020-09-01  2020  September
# 9     2020-10   12387725        1238546471  ... 2020-10-01  2020    October
# 10    2020-11   17067489        1655556836  ... 2020-11-01  2020   November
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
ax=sns.lineplot(x='Month',y='New_cases',hue='Year',data=monthly_data)
ax.set(title='Monthly cases variation for 2020 and 2021')
# Out:
# [Text(0.5, 1.0, 'Monthly cases variation for 2020 and 2021')]

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
ax=sns.lineplot(x='Month',y='New_deaths',hue='Year',data=monthly_data)
ax.set(title='Monthly deaths variation for 2020 and 2021')
# Out:
# [Text(0.5, 1.0, 'Monthly deaths variation for 2020 and 2021')]

# %%
latest_cases_death_transmission_data=pd.read_csv('https://covid19.who.int/WHO-COVID-19-global-table-data.csv')
cols=latest_cases_death_transmission_data.columns
latest_cases_death_transmission_data.reset_index(inplace=True)
latest_cases_death_transmission_data.drop(columns=['Deaths - newly reported in last 24 hours'],inplace=True)
latest_cases_death_transmission_data.columns=cols
latest_cases_death_transmission_data
# Out:
#                          Name  ... Deaths - newly reported in last 24 hours
# 0                      Global  ...                                     8600
# 1    United States of America  ...                                     1056
# 2                       India  ...                                      540
# 3                      Brazil  ...                                     1064
# 4          Russian Federation  ...                                      785
# ..                        ...  ...                                      ...
# 233              Saint Helena  ...                                        0
# 234                   Tokelau  ...                                        0
# 235                     Tonga  ...                                        0
# 236              Turkmenistan  ...                                        0
# 237                    Tuvalu  ...                                        0
#
# [238 rows x 12 columns]

# %%
latest_cases_death_transmission_data.nlargest(11, 'Cases - cumulative total per 100000 population')
# Out:
#                  Name  ... Deaths - newly reported in last 24 hours
# 144        Seychelles  ...                                        0
# 151           Andorra  ...                                        0
# 108        Montenegro  ...                                       11
# 78            Bahrain  ...                                        0
# 23            Czechia  ...                                        2
# 181         Gibraltar  ...                                        0
# 198  Saint Barthélemy  ...                                        0
# 182        San Marino  ...                                        0
# 114          Maldives  ...                                        0
# 156             Aruba  ...                                        0
# 130  French Polynesia  ...                                       10
#
# [11 rows x 12 columns]

# %%
latest_cases_death_transmission_data.nlargest(11, 'Cases - cumulative total')
# Out:
#                         Name  ... Deaths - newly reported in last 24 hours
# 0                     Global  ...                                     8600
# 1   United States of America  ...                                     1056
# 2                      India  ...                                      540
# 3                     Brazil  ...                                     1064
# 4         Russian Federation  ...                                      785
# 5         The United Kingdom  ...                                      113
# 6                     France  ...                                      105
# 7                     Turkey  ...                                      216
# 8                  Argentina  ...                                      247
# 9                   Colombia  ...                                       93
# 10                     Spain  ...                                       22
#
# [11 rows x 12 columns]

# %%
latest_cases_death_transmission_data.isnull().sum()
# Out:
# Name                                                            0
# WHO Region                                                      1
# Cases - cumulative total                                        0
# Cases - cumulative total per 100000 population                  1
# Cases - newly reported in last 7 days                           0
# Cases - newly reported in last 7 days per 100000 population     1
# Cases - newly reported in last 24 hours                         0
# Deaths - cumulative total                                       0
# Deaths - cumulative total per 100000 population                 1
# Deaths - newly reported in last 7 days                          0
# Deaths - newly reported in last 7 days per 100000 population    1
# Deaths - newly reported in last 24 hours                        0
# dtype: int64

# %%
latest_cases_death_transmission_data[latest_cases_death_transmission_data['Cases - newly reported in last 7 days per 100000 population'].isnull()]
# Out:
#       Name  ... Deaths - newly reported in last 24 hours
# 205  Other  ...                                        0
#
# [1 rows x 12 columns]

# %%
latest_cases_death_transmission_data.nlargest(11, 'Cases - cumulative total')
# Out:
#                         Name  ... Deaths - newly reported in last 24 hours
# 0                     Global  ...                                     8600
# 1   United States of America  ...                                     1056
# 2                      India  ...                                      540
# 3                     Brazil  ...                                     1064
# 4         Russian Federation  ...                                      785
# 5         The United Kingdom  ...                                      113
# 6                     France  ...                                      105
# 7                     Turkey  ...                                      216
# 8                  Argentina  ...                                      247
# 9                   Colombia  ...                                       93
# 10                     Spain  ...                                       22
#
# [11 rows x 12 columns]

# %%
vaccination_data=pd.read_csv('https://covid19.who.int/who-data/vaccination-data.csv')
vc=vaccination_data
vaccination_data.isnull().sum()
# Out:
# COUNTRY                                  0
# ISO3                                     0
# WHO_REGION                               0
# DATA_SOURCE                              0
# DATE_UPDATED                             0
# TOTAL_VACCINATIONS                       1
# PERSONS_VACCINATED_1PLUS_DOSE            8
# TOTAL_VACCINATIONS_PER100                1
# PERSONS_VACCINATED_1PLUS_DOSE_PER100     8
# PERSONS_FULLY_VACCINATED                10
# PERSONS_FULLY_VACCINATED_PER100         10
# VACCINES_USED                            4
# FIRST_VACCINE_DATE                      72
# NUMBER_VACCINES_TYPES_USED               4
# dtype: int64

# %%
vaccination_data['FIRST_VACCINE_DATE'].fillna('Not available',inplace=True)

# %%
vaccination_data['VACCINES_USED'].fillna('Not available',inplace=True)

# %%
vaccination_data['PERSONS_FULLY_VACCINATED_PER100'].fillna('Not available',inplace=True)

# %%
vaccination_data['PERSONS_FULLY_VACCINATED'].fillna('Not available',inplace=True)

# %%
vaccination_data['PERSONS_VACCINATED_1PLUS_DOSE_PER100'].fillna('Not available',inplace=True)

# %%
vaccination_data['TOTAL_VACCINATIONS_PER100'].fillna('Not available',inplace=True)

# %%
vaccination_data['TOTAL_VACCINATIONS'].fillna('Not available',inplace=True)

# %%
def country_data(country):
  cdf=daily_cases_data[daily_cases_data['Country']==country]
  cdf['Month_Year']=cdf['Date_reported'].dt.strftime('%Y-%m')
  cdf['Year'] = cdf['Date_reported'].dt.strftime('%Y')
  cdf['day']=cdf['Date_reported'].dt.strftime('%m-%d')
  total_t_cou=latest_cases_death_transmission_data[latest_cases_death_transmission_data['Name']==country]
  vac_dat=vaccination_data[vaccination_data['COUNTRY']==country]
  print('Total number of cases for ',country,' is ',total_t_cou['Cases - cumulative total'].values)
  print('Total number of deaths for ',country,' is ',total_t_cou['Deaths - cumulative total'].values)
  print('Total number of cases in the last seven days for ',country,' is ',total_t_cou['Cases - newly reported in last 7 days'].values)
  print('Total number of deaths in the last seven days for ',country,' is ',total_t_cou['Deaths - newly reported in last 7 days'].values)
  print('Total number of cases in the last seven days per 100000 people for ',country,' is ',total_t_cou['Cases - newly reported in last 7 days per 100000 population'].values)
  print('Total number of deaths in the last seven days per 100000 people for ',country,' is ',total_t_cou['Deaths - cumulative total per 100000 population'].values)
  print('First vaccination date for ',country,' is ',vac_dat['FIRST_VACCINE_DATE'].values)
  fig, ax = plt.subplots(1, 1, figsize=(20, 10))
  ax=sns.lineplot(x='Date_reported',y='New_cases',data=cdf)
  figd, axd = plt.subplots(1, 1, figsize=(20, 10))
  axd=sns.lineplot(x='Date_reported',y='New_deaths',data=cdf)
  #fig1, ax1 = plt.subplots(1, 1, figsize=(20, 10))
  #ax1=sns.lineplot(x='Month',y='New_cases',hue='Year',data=cdf)
  #fig2, ax2 = plt.subplots(1, 1, figsize=(20, 10))
  #ax2=sns.lineplot(x='Month',y='New_deaths',hue='Year',data=cdf)
  if country=='China':
    print('No vaccine data available')
  elif country=='Gibraltar':
    print('Reported vaccination percentage is more than 100')
  else:
    vr=vac_dat['PERSONS_FULLY_VACCINATED_PER100'].values
    uvr=100-int(vr[0])
    cnt_vac=pd.DataFrame({'percentage':[int(vr[0]),uvr]},index=['vaccinated','unvaccinated'])
    cnt_vac.plot.pie(y='percentage',autopct="%.1f%%",figsize=(8, 8));

# %%
country_data('India')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('United States of America')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('China')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Pakistan')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Mexico')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Indonesia')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Bangladesh')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Nigeria')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Brazil')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Russian Federation')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
vc
# Out:
#                COUNTRY ISO3  ... FIRST_VACCINE_DATE NUMBER_VACCINES_TYPES_USED
# 0          Afghanistan  AFG  ...         2021-02-22                        4.0
# 1              Albania  ALB  ...      Not available                        4.0
# 2              Algeria  DZA  ...         2021-01-30                        3.0
# 3       American Samoa  ASM  ...         2020-12-21                        3.0
# 4              Andorra  AND  ...      Not available                        2.0
# ..                 ...  ...  ...                ...                        ...
# 222           Viet Nam  VNM  ...         2021-03-08                        5.0
# 223  Wallis and Futuna  WLF  ...         2021-03-19                        1.0
# 224              Yemen  YEM  ...         2021-04-20                        1.0
# 225             Zambia  ZMB  ...         2021-04-14                        1.0
# 226           Zimbabwe  ZWE  ...         2021-02-18                        3.0
#
# [227 rows x 14 columns]

# %%
vc=pd.read_csv('https://covid19.who.int/who-data/vaccination-data.csv')
vc['PERSONS_FULLY_VACCINATED'] = vc['PERSONS_FULLY_VACCINATED'].astype(str).astype(float)

# %%
vc.dtypes
# Out:
# COUNTRY                                  object
# ISO3                                     object
# WHO_REGION                               object
# DATA_SOURCE                              object
# DATE_UPDATED                             object
# TOTAL_VACCINATIONS                      float64
# PERSONS_VACCINATED_1PLUS_DOSE           float64
# TOTAL_VACCINATIONS_PER100               float64
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    float64
# PERSONS_FULLY_VACCINATED                float64
# PERSONS_FULLY_VACCINATED_PER100         float64
# VACCINES_USED                            object
# FIRST_VACCINE_DATE                       object
# NUMBER_VACCINES_TYPES_USED              float64
# dtype: object

# %%
vc['PERSONS_FULLY_VACCINATED'].sum()
# Out:
# 1029756684.0

# %%
vc['TOTAL_VACCINATIONS'].sum()
# Out:
# 4562256778.0

# %%
ctr=latest_cases_death_transmission_data

# %%
import plotly.express as px

# %%
figure = px.choropleth(ctr,locations='Name', locationmode='country names', color='Cases - cumulative total', hover_name='Name', color_continuous_scale='tealgrn', range_color=[1,1000000],title='Countries with Confirmed cases',width=1000,height=600)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="25d39b2c-a2eb-4edf-a535-7759f9dce1df" class="plotly-graph-div" style="height:600px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("25d39b2c-a2eb-4edf-a535-7759f9dce1df")) {
#                     Plotly.newPlot(
#                         '25d39b2c-a2eb-4edf-a535-7759f9dce1df',
# ...

# %%
deathfigure = px.choropleth(ctr,locations='Name', locationmode='country names', color='Deaths - cumulative total', hover_name='Name', color_continuous_scale='reds', range_color=[1,1000000],title='Countries with Confirmed deaths',width=1000,height=600)
deathfigure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9e3fa2b1-341e-468b-ae6c-c7762fb02aeb" class="plotly-graph-div" style="height:600px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9e3fa2b1-341e-468b-ae6c-c7762fb02aeb")) {
#                     Plotly.newPlot(
#                         '9e3fa2b1-341e-468b-ae6c-c7762fb02aeb',
# ...

# %%
vacc=pd.read_csv('https://covid19.who.int/who-data/vaccination-data.csv')

# %%
vacc.fillna(value = 0, inplace = True)
vacc.TOTAL_VACCINATIONS = vacc.TOTAL_VACCINATIONS.astype(int)
vacc.PERSONS_VACCINATED_1PLUS_DOSE = vacc.PERSONS_VACCINATED_1PLUS_DOSE.astype(int)
vacc.PERSONS_FULLY_VACCINATED = vacc.PERSONS_FULLY_VACCINATED.astype(int)
date = vacc.DATE_UPDATED.str.split('-', expand =True)
date
# Out:
#         0   1   2
# 0    2021  08  11
# 1    2021  08  17
# 2    2021  08  20
# 3    2021  08  09
# 4    2021  08  15
# ..    ...  ..  ..
# 222  2021  08  13
# 223  2021  07  22
# 224  2021  07  27
# 225  2021  08  20
# 226  2021  08  20
#
# [227 rows x 3 columns]

# %%
vacc['year'] = date[0]
vacc['month'] = date[1]
vacc['day'] = date[2]
vacc.year = pd.to_numeric(vacc.year)
vacc.month = pd.to_numeric(vacc.month)
vacc.day = pd.to_numeric(vacc.day)
vacc.date = pd.to_datetime(vacc.DATE_UPDATED)
vacc.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#           COUNTRY ISO3 WHO_REGION  ...  year month  day
# 0     Afghanistan  AFG       EMRO  ...  2021     8   11
# 1         Albania  ALB       EURO  ...  2021     8   17
# 2         Algeria  DZA       AFRO  ...  2021     8   20
# 3  American Samoa  ASM       WPRO  ...  2021     8    9
# 4         Andorra  AND       EURO  ...  2021     8   15
#
# [5 rows x 17 columns]

# %%
print('Data point starts from ',vacc.date.min())
print('Data point ends at ',vacc.date.max())
print('Total no of countries in the data set ',len(vacc.COUNTRY.unique()))
print('Total no of unique vaccines in the data set ',len(vacc.VACCINES_USED.unique()))
# Out:
# Data point starts from  2021-04-04 00:00:00
# Data point ends at  2021-08-20 00:00:00
# Total no of countries in the data set  227
# Total no of unique vaccines in the data set  104

# %%
from wordcloud import WordCloud
import plotly.express as px

# %%
sns.set(color_codes = True)
sns.set(style="whitegrid")

# %%
wordCloud = WordCloud(
    background_color='white',
    max_font_size = 50).generate(' '.join(vacc.COUNTRY))
plt.figure(figsize=(15,7))
plt.axis('off')
plt.imshow(wordCloud)
plt.show()

# %%
country_wise_total_vaccinated = {}
for COUNTRY in vacc.COUNTRY.unique() : 
    vaccinated = 0
    for i in range(len(vacc)) : 
        if vacc.COUNTRY[i] == COUNTRY : 
            vaccinated += int(vacc.PERSONS_FULLY_VACCINATED[i])
    country_wise_total_vaccinated[COUNTRY] = vaccinated 

    country_wise_total_vaccinated_df = pd.DataFrame.from_dict(country_wise_total_vaccinated,
                                                         orient='index',
                                                         columns = ['total_vaccinted_till_date'])
    
country_wise_total_vaccinated_df.sort_values(by = 'total_vaccinted_till_date', ascending = False, inplace = True)
country_wise_total_vaccinated_df
# Out:
#                           total_vaccinted_till_date
# United States of America                  167928517
# India                                     124931974
# Germany                                    48419275
# Brazil                                     45412687
# The United Kingdom                         40703769
# ...                                             ...
# Uzbekistan                                        0
# Guernsey                                          0
# Tokelau                                           0
# Kuwait                                            0
# Republic of Moldova                               0
#
# [227 rows x 1 columns]

# %%
fig = px.bar(country_wise_total_vaccinated_df, 
             y = 'total_vaccinted_till_date',
             x = country_wise_total_vaccinated_df.index,
             color = 'total_vaccinted_till_date',
             color_discrete_sequence= px.colors.sequential.Viridis_r
            )
fig.update_layout(
    title={
            'text' : "Vaccination till date in various countries",
            'y':0.95,
            'x':0.5
        },
    xaxis_title="Countries",
    yaxis_title="Total vaccinated")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d19a90fe-fab2-4565-8947-353fbe143b92" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d19a90fe-fab2-4565-8947-353fbe143b92")) {
#                     Plotly.newPlot(
#                         'd19a90fe-fab2-4565-8947-353fbe143b92',
# ...

# %%
vaccination_meta_data=pd.read_csv('https://covid19.who.int/who-data/vaccination-metadata.csv')
vaccination_meta_data.isnull().sum()
# Out:
# ISO3                    0
# VACCINE_NAME            0
# PRODUCT_NAME            2
# COMPANY_NAME            2
# AUTHORIZATION_DATE    529
# START_DATE            227
# END_DATE              730
# COMMENT               730
# DATA_SOURCE             0
# dtype: int64

# %%
vaccm=vaccination_meta_data

# %%
del vaccm['END_DATE']
del vaccm['COMMENT']

# %%
vaccm.isnull().sum()
# Out:
# ISO3                    0
# VACCINE_NAME            0
# PRODUCT_NAME            2
# COMPANY_NAME            2
# AUTHORIZATION_DATE    529
# START_DATE            227
# DATA_SOURCE             0
# dtype: int64

# %%
def plot_pie(value, title, color) : 
    new_dict = {}
    for v in vaccm[value].unique() : 
        value_count = 0
        for i in range(len(vaccm)) : 
            if vaccm[value][i] == v : 
                value_count += 1 
        new_dict[v] = value_count 

    new_df = pd.DataFrame.from_dict(new_dict, orient = 'index', columns = ['Total'])
    if color == 'plasma' : 
        fig = px.pie(new_df, values= 'Total',
                     names = new_df.index,
                     title = title,
                     color_discrete_sequence=px.colors.sequential.Plasma)
    elif color == 'rainbow' : 
        fig = px.pie(new_df, values= 'Total',
                     names = new_df.index,
                     title = title,
                     color_discrete_sequence=px.colors.sequential.Rainbow)
    else :
        fig = px.pie(new_df, values= 'Total',
                     names = new_df.index,
                     title = title)
    fig.update_layout(
        title={
            'y':0.95,
            'x':0.5
        })
    return fig.show()
plot_pie('VACCINE_NAME', 'Various vaccines and their gloabal usage', 'plasma')
plot_pie('COMPANY_NAME', 'Various companies for their vaccine share', 'rainbow')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="31001a9b-cbac-4ae6-bf62-63627fc268a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("31001a9b-cbac-4ae6-bf62-63627fc268a1")) {
#                     Plotly.newPlot(
#                         '31001a9b-cbac-4ae6-bf62-63627fc268a1',
# ...

# %%
wordCloud = WordCloud(
    background_color='white',
    max_font_size = 50).generate(' '.join(vaccm.VACCINE_NAME))
plt.figure(figsize=(12,5))
plt.axis('off')
plt.imshow(wordCloud)
plt.show()

# %%
fig = px.bar(vacc, x = 'COUNTRY', y ='PERSONS_FULLY_VACCINATED', color = 'COUNTRY',width=1500,height=800)
fig.update_layout(
    title={
            'text' : "vaccination trend",
        },
    yaxis_title="Fully Vaccinated people"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e2d2d8d5-8a99-4064-882b-d5a62db1ac2a" class="plotly-graph-div" style="height:800px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2d2d8d5-8a99-4064-882b-d5a62db1ac2a")) {
#                     Plotly.newPlot(
#                         'e2d2d8d5-8a99-4064-882b-d5a62db1ac2a',
# ...

# %%
#IND VS USA

india_usa = [vacc[vacc.COUNTRY == 'United States of America'], vacc[vacc.COUNTRY == 'India']]
res = pd.concat(india_usa)
fig = px.bar(res, x = 'COUNTRY', y ='TOTAL_VACCINATIONS', color = 'TOTAL_VACCINATIONS',width=1000, height=500)
fig.update_layout(
    title={
            'text' : "Total vaccinated - India vs USA",
            'y':0.95,
            'x':0.5
        },
    yaxis_title="Total Vaccinations"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="63280ae2-7bb1-4908-a638-62970896feae" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("63280ae2-7bb1-4908-a638-62970896feae")) {
#                     Plotly.newPlot(
#                         '63280ae2-7bb1-4908-a638-62970896feae',
# ...

# %%
#top 5

top5 = [vacc[vacc.COUNTRY == 'United States of America'], vacc[vacc.COUNTRY == 'India'], vacc[vacc.COUNTRY == 'China'],vacc[vacc.COUNTRY == 'Brazil'],vacc[vacc.COUNTRY == 'Japan']]
res = pd.concat(top5)
fig = px.bar(res, x = 'COUNTRY', y ='TOTAL_VACCINATIONS', color = 'TOTAL_VACCINATIONS',width=1200, height= 600)
fig.update_layout(
    title={
            'text' : "Total vaccinations of Top 5 countries",
            'y':0.95,
            'x':0.5
        },
    yaxis_title="Total Vaccinations"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7b4e83da-ff37-4b41-9abf-266415bc6f50" class="plotly-graph-div" style="height:600px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7b4e83da-ff37-4b41-9abf-266415bc6f50")) {
#                     Plotly.newPlot(
#                         '7b4e83da-ff37-4b41-9abf-266415bc6f50',
# ...

# %%
latest_cases_death_transmission_data.nlargest(11,'Cases - newly reported in last 7 days')
# Out:
#                           Name  ... Deaths - newly reported in last 24 hours
# 0                       Global  ...                                     8600
# 1     United States of America  ...                                     1056
# 11  Iran (Islamic Republic of)  ...                                      564
# 2                        India  ...                                      540
# 3                       Brazil  ...                                     1064
# 5           The United Kingdom  ...                                      113
# 4           Russian Federation  ...                                      785
# 25                    Malaysia  ...                                      178
# 34                    Thailand  ...                                      240
# 6                       France  ...                                      105
# 28                       Japan  ...                                       33
#
# [11 rows x 12 columns]

# %%
latest_cases_death_transmission_data.nsmallest(20,'Cases - newly reported in last 7 days')
# Out:
#                                       Name  ... Deaths - newly reported in last 24 hours
# 112                               Cameroon  ...                                        0
# 161               Central African Republic  ...                                        0
# 200            United Republic of Tanzania  ...                                        0
# 205                                  Other  ...                                        0
# 208                      Wallis and Futuna  ...                                        0
# 213                          New Caledonia  ...                                        0
# 214            Falkland Islands (Malvinas)  ...                                        0
# 215              Saint Pierre and Miquelon  ...                                        0
# 216                               Holy See  ...                                        0
# ...

# %%
latest_cases_death_transmission_data.nsmallest(11,'Cases - cumulative total')
# Out:
#                                       Name  ... Deaths - newly reported in last 24 hours
# 224                         American Samoa  ...                                        0
# 225                           Cook Islands  ...                                        0
# 226  Democratic People's Republic of Korea  ...                                        0
# 227                               Kiribati  ...                                        0
# 228       Micronesia (Federated States of)  ...                                        0
# 229                                  Nauru  ...                                        0
# 230                                   Niue  ...                                        0
# 231                                  Palau  ...                                        0
# 232                       Pitcairn Islands  ...                                        0
# ...

# %%
latest_cases_death_transmission_data.nlargest(11,'Cases - newly reported in last 7 days per 100000 population')
# Out:
#                  Name  ... Deaths - newly reported in last 24 hours
# 130  French Polynesia  ...                                       10
# 132        Guadeloupe  ...                                        0
# 201          Dominica  ...                                        1
# 134        Martinique  ...                                       21
# 50            Georgia  ...                                       59
# 198  Saint Barthélemy  ...                                        0
# 156             Aruba  ...                                        0
# 95           Botswana  ...                                       38
# 102         Kosovo[1]  ...                                        8
# 189      Saint Martin  ...                                        0
# 47               Cuba  ...                                       79
#
# [11 rows x 12 columns]

# %%
vacc.nlargest(10,'PERSONS_FULLY_VACCINATED_PER100')
# Out:
#               COUNTRY ISO3 WHO_REGION  ...  year month  day
# 78          Gibraltar  GIB       EURO  ...  2021     8   17
# 125             Malta  MLT       EURO  ...  2021     8   17
# 155             Palau  PLW       WPRO  ...  2021     8    9
# 38     Cayman Islands  CYM       AMRO  ...  2021     8   13
# 161  Pitcairn Islands  PCN       WPRO  ...  2021     7   22
# 98        Isle of Man  IMN       EURO  ...  2021     8   17
# 148              Niue  NIU       WPRO  ...  2021     8    2
# 182        Seychelles  SYC       AFRO  ...  2021     8   20
# 92            Iceland  ISL       EURO  ...  2021     8    6
# 177        San Marino  SMR       EURO  ...  2021     8   17
#
# [10 rows x 17 columns]

# %%
country_data('Palau')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Malta')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Gibraltar')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
country_data('Palau')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
